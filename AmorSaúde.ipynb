# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielGuilherme88/analises/blob/main/AmorSa%C3%BAde.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas.io.sql as sqlio
import sys
import psycopg2

# %%
query_contas_a_receber = 'select * from tb_consolidacao_contas_a_receber_modelagem where data_pagamento between ''2022-01-01'' and ''2023-01-01'''

# %%
query_funcionarios = "select sf.id, sf.nome_funcionario , sf.sys_user , sf.ativo , sf.sys_active, sf.nascimento, sf.cpf,sf.celular , sf.estado , sf.cidade , sf.centro_custo_id , sf.setor_colaborador , sf.cargo_colaborador_unidade,sf.sexo_id, su.nome_fantasia, su.regiao from stg_funcionarios sf left join stg_funcionarios_unidades sfu on sfu.funcionario_id = sf.id left join stg_unidades su on su.id = sfu.unidade_id"

# %%
connection = psycopg2.connect(dbname="dw_amorsaude", 
                  user="gabriel_guilherme", 
                  password="PgQ1yBg9hzHJfmc",
                  host ="amorsaude-cluster-redshift.cmc4ev2oyczd.us-east-1.redshift.amazonaws.com",
                  port = 5439)

df = pd.read_sql_query(query_funcionarios,con=connection)
print(df.head(5))
# Out:
# <ipython-input-4-cd6d33983175>:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query_funcionarios,con=connection)
#        id                 nome_funcionario   sys_user ativo  sys_active  \
# 0  159651                  Gabriel Cardoso          0                 1
# 1  174521      Janiele Lopes De Figueiredo     142191                 1
# 2  182019       Brenda Machado De Carvalho     142144    on           1
# 3  189045           fernanda lima dos reis     181622    on           1
# 4  195516  Alexandra Maristeles De Menezes  150012105                 1
#
#    nascimento             cpf          celular estado         cidade  \
# 0  1998-11-27     06041777129             None     MT  Várzea Grande
# 1        None     40522573835
# 2  2003-06-28  055.980.500-48  (51) 98351-0086     RS       Gravataí
# ...

# %%
#pip install ydata-profiling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.9/345.9 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 11.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 28.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 31.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 24.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 59.4 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27096 sha256=3a9541f8587da19046598ac22ff960521004e7d52d5a7f721de02d9f4312791f
# ...

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df)

# %%
profile.to_notebook_iframe()
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.1.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-05-04 19:11:14.385628&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_widgets()
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:498: UserWarning: Ipywidgets is not yet fully supported on Google Colab (https://github.com/googlecolab/colabtools/issues/60).As an alternative, you can use the HTML report. See the documentation for more information.
#   warnings.warn(
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
